# %% [markdown]
# # Sentiment analysis

# %% [markdown]
# ## Loading files & dependency

# %%
import numpy as np
from numpy import interp

np.set_printoptions(threshold=10000,suppress=True)
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import gc

# %%
import os
import json
import random
from pathlib import Path
from zipfile import ZipFile

# %%
# !pip3 install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from seaborn) (1.22.2)
# Requirement already satisfied: pandas>=0.23 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: scipy>=1.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: matplotlib>=2.2 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
# !pip3 install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: pillow in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from wordcloud) (1.22.2)
# Requirement already satisfied: matplotlib in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# !pip3 install textblob textblob_fr
# Out:
# Requirement already satisfied: textblob in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (0.15.3)
# Requirement already satisfied: textblob_fr in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: nltk>=3.1 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from textblob) (3.6.7)
# Requirement already satisfied: joblib in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2022.3.2)
# Requirement already satisfied: click in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: tqdm in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.63.0)

# %%
# !pip3 install plotly
# Out:
# Requirement already satisfied: plotly in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /Users/florent-haffner/opt/anaconda3/envs/ml_communes/lib/python3.9/site-packages (from plotly) (1.16.0)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import string
import re

# %%
# pd.set_option('max_colwidth', None)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

import spacy
from spacy.lang.fr.stop_words import STOP_WORDS

from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer

import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv('../../Resources/communes_commentaire.csv', delimiter=';'); df.head()
# Out:
#    Insee  Code_postal              Ville  Sécurité  Éducation  Sport / Loisir  \
# 0   1004         1500  Ambérieu-en-Bugey       5.0        4.0             5.0
# 1   1004         1500  Ambérieu-en-Bugey       4.0        4.0             4.0
# 2   1004         1500  Ambérieu-en-Bugey       5.0        5.0             4.0
# 3   1004         1500  Ambérieu-en-Bugey       2.0        4.0             2.0
# 4   1004         1500  Ambérieu-en-Bugey       4.0        2.0             3.0
#
#    Environnement  Vie pratique  pouce_positif  pouce_negatif  \
# 0            5.0           4.0              2              0
# 1            4.0           3.0              0              1
# 2            4.0           4.0              0              0
# 3            4.0           2.0              0              0
# 4            3.0           3.0              0              0
#
#                                          commentaire        date  \
# 0  Ville très agréable, tranquille et disposant d...  15/05/2021
# 1  La police et la gendarmerie peuvent se montrer...  03/03/2021
# 2                   Ville ou sa ne vis pas beaucoup   04/11/2020
# 3  C’est une belle ville mais peu d’activités (sp...  20/08/2019
# 4  Aspects positifs: la mixité sociale, cohabitat...  13/04/2018
#
#              auteur
# 0              INNO
# 1              Jane
# 2          lilalou
# 3         Le tounsi
# 4  Laetitialexandre

# %%
data = df.copy()
data.shape
# Out:
# (24344, 13)

# %%
NAN = [(c, data[c].isna().mean()*100) for c in data]
NAN = pd.DataFrame(NAN, columns=["column_name", "percentage"])
NAN.sort_values("percentage", ascending=False)
# Out:
#        column_name  percentage
# 3         Sécurité    2.805619
# 4        Éducation    2.805619
# 5   Sport / Loisir    2.805619
# 6    Environnement    2.805619
# 7     Vie pratique    2.805619
# 0            Insee    0.000000
# 1      Code_postal    0.000000
# 2            Ville    0.000000
# 8    pouce_positif    0.000000
# 9    pouce_negatif    0.000000
# 10     commentaire    0.000000
# 11            date    0.000000
# 12          auteur    0.000000

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (23661, 13)

# %%
NAN = [(c, data[c].isna().mean()*100) for c in data]
NAN = pd.DataFrame(NAN, columns=["column_name", "percentage"])
NAN.sort_values("percentage", ascending=False)
# Out:
#        column_name  percentage
# 0            Insee         0.0
# 1      Code_postal         0.0
# 2            Ville         0.0
# 3         Sécurité         0.0
# 4        Éducation         0.0
# 5   Sport / Loisir         0.0
# 6    Environnement         0.0
# 7     Vie pratique         0.0
# 8    pouce_positif         0.0
# 9    pouce_negatif         0.0
# 10     commentaire         0.0
# 11            date         0.0
# 12          auteur         0.0

# %% [markdown]
# ## Data processing

# %%
data['Comment'] = data['commentaire'].apply(lambda f: f.lower())

# %%
AComment=[]
for comment in data["Comment"].apply(str):
    Word_Tok = []
    for word in  re.sub("\W"," ",comment ).split():
        Word_Tok.append(word)
    AComment.append(Word_Tok)

# %%
data["Word_Tok"] = AComment
data.head(5)
# Out:
#    Insee  Code_postal              Ville  Sécurité  Éducation  Sport / Loisir  \
# 0   1004         1500  Ambérieu-en-Bugey       5.0        4.0             5.0
# 1   1004         1500  Ambérieu-en-Bugey       4.0        4.0             4.0
# 2   1004         1500  Ambérieu-en-Bugey       5.0        5.0             4.0
# 3   1004         1500  Ambérieu-en-Bugey       2.0        4.0             2.0
# 4   1004         1500  Ambérieu-en-Bugey       4.0        2.0             3.0
#
#    Environnement  Vie pratique  pouce_positif  pouce_negatif  \
# 0            5.0           4.0              2              0
# 1            4.0           3.0              0              1
# 2            4.0           4.0              0              0
# 3            4.0           2.0              0              0
# 4            3.0           3.0              0              0
#
#                                          commentaire        date  \
# 0  Ville très agréable, tranquille et disposant d...  15/05/2021
# 1  La police et la gendarmerie peuvent se montrer...  03/03/2021
# 2                   Ville ou sa ne vis pas beaucoup   04/11/2020
# 3  C’est une belle ville mais peu d’activités (sp...  20/08/2019
# 4  Aspects positifs: la mixité sociale, cohabitat...  13/04/2018
#
#              auteur                                            Comment  \
# 0              INNO  ville très agréable, tranquille et disposant d...
# 1              Jane  la police et la gendarmerie peuvent se montrer...
# 2          lilalou                    ville ou sa ne vis pas beaucoup
# 3         Le tounsi  c’est une belle ville mais peu d’activités (sp...
# 4  Laetitialexandre  aspects positifs: la mixité sociale, cohabitat...
#
#                                             Word_Tok
# 0  [ville, très, agréable, tranquille, et, dispos...
# 1  [la, police, et, la, gendarmerie, peuvent, se,...
# 2            [ville, ou, sa, ne, vis, pas, beaucoup]
# 3  [c, est, une, belle, ville, mais, peu, d, acti...
# 4  [aspects, positifs, la, mixité, sociale, cohab...

# %%
stop_words=set(STOP_WORDS)

# deselect_stop_words = ['n\'', 'ne','pas','plus','personne','aucun','ni','aucune','rien']
# for w in deselect_stop_words:
#     if w in stop_words:
#         stop_words.remove(w)
#     else:
#         continue

# %%
WORDS_TO_REMOVE = set(['qu', 'faire', 'faut', 'ans'])

stop_words.update(WORDS_TO_REMOVE)

# %%
AllfilteredComment=[]
for comment in data["Word_Tok"]:
    filteredComment = [w for w in comment if not ((w in stop_words) or (len(w) == 1))]
    AllfilteredComment.append(' '.join(filteredComment))

# %%
data["CommentAferPreproc"]=AllfilteredComment
data.head(5)
# Out:
#    Insee  Code_postal              Ville  Sécurité  Éducation  Sport / Loisir  \
# 0   1004         1500  Ambérieu-en-Bugey       5.0        4.0             5.0
# 1   1004         1500  Ambérieu-en-Bugey       4.0        4.0             4.0
# 2   1004         1500  Ambérieu-en-Bugey       5.0        5.0             4.0
# 3   1004         1500  Ambérieu-en-Bugey       2.0        4.0             2.0
# 4   1004         1500  Ambérieu-en-Bugey       4.0        2.0             3.0
#
#    Environnement  Vie pratique  pouce_positif  pouce_negatif  \
# 0            5.0           4.0              2              0
# 1            4.0           3.0              0              1
# 2            4.0           4.0              0              0
# 3            4.0           2.0              0              0
# 4            3.0           3.0              0              0
#
#                                          commentaire        date  \
# 0  Ville très agréable, tranquille et disposant d...  15/05/2021
# 1  La police et la gendarmerie peuvent se montrer...  03/03/2021
# 2                   Ville ou sa ne vis pas beaucoup   04/11/2020
# 3  C’est une belle ville mais peu d’activités (sp...  20/08/2019
# 4  Aspects positifs: la mixité sociale, cohabitat...  13/04/2018
#
#              auteur                                            Comment  \
# 0              INNO  ville très agréable, tranquille et disposant d...
# 1              Jane  la police et la gendarmerie peuvent se montrer...
# 2          lilalou                    ville ou sa ne vis pas beaucoup
# 3         Le tounsi  c’est une belle ville mais peu d’activités (sp...
# 4  Laetitialexandre  aspects positifs: la mixité sociale, cohabitat...
#
#                                             Word_Tok  \
# 0  [ville, très, agréable, tranquille, et, dispos...
# 1  [la, police, et, la, gendarmerie, peuvent, se,...
# 2            [ville, ou, sa, ne, vis, pas, beaucoup]
# 3  [c, est, une, belle, ville, mais, peu, d, acti...
# 4  [aspects, positifs, la, mixité, sociale, cohab...
#
#                                   CommentAferPreproc
# 0  ville agréable tranquille disposant commodités...
# 1  police gendarmerie montrer trop répressives in...
# 2                                 ville vis beaucoup
# 3       belle ville activités sportifs divertissante
# 4  aspects positifs mixité sociale cohabitation h...

# %%
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())

for i in data['CommentAferPreproc'][:10]:
    sentiment = tb(i).sentiment
    polarity = tb(i).polarity
    print(i, sentiment)
# Out:
# ville agréable tranquille disposant commodités commerces écoles gare clubs sport clinique ville trop loin lyon pied montagnes profiter nature (0.2125, 0.5)
# police gendarmerie montrer trop répressives infractions stationnements conciliantes zones véhicules bref poids mesures difficile accepter (-0.1925, 0.275)
# ville vis beaucoup (0.1, 0.1)
# belle ville activités sportifs divertissante (0.45, 0.5)
# aspects positifs mixité sociale cohabitation habitants mélange culture accès culture quartiers défavorisés aspects négatifs choses proposés faible cout (-0.043333333333333335, 0.16666666666666666)
# ville province trop incivilités beaucoup choses faites transport personnes maison medicalisées bien (-0.049999999999999996, 0.3333333333333333)
# bonne commune tri déchets rues propres écoles neuves manque commerce (0.3025, 0.325)
# prêt partir ville (0.14, 0.15)
# positif belles forêts beaux lacs loin négatif animation centre ville animé mort (0.5333333333333333, 0.5333333333333333)
# petite ville sympathique dotée commodités utiles agréable vie écoles commerces proximité hôpital (0.39999999999999997, 0.375)

# %%
senti_list = []
confidence_list = []

for i in data["CommentAferPreproc"]:
    vs = tb(i).sentiment[0]
    
    if (vs > 0.2):
        senti_list.append('Positive')
    elif (vs < -0.2):
        senti_list.append('Negative')
    else:
        senti_list.append('Neutral')
        
    confidence = interp(vs, [-1,1], [1,100])
    confidence_list.append(round(confidence, 2))

# %%
data["sentiment"] = senti_list
data["sentiment_confidence"] = confidence_list

# %% [markdown]
# 1. Computing mean scoring
# 2. Computing confusion matrix

# %% [markdown]
# ## Analysing data based on sentiment

# %%
nb_pos=np.sum(data['sentiment']=='Positive')
nb_neg=np.sum(data['sentiment']=='Negative')
nb_neutral = np.sum(data['sentiment']=='Neutral')

print(f'Positive: {nb_pos*100/len(data):.2f}%, negative: {nb_neg*100/len(data):.2f}%, neutre: {nb_neutral*100/len(data):.2f}%')
# Out:
# Positive: 47.31%, negative: 4.14%, neutre: 48.55%

# %%
plt.pie(data['sentiment'].value_counts()*100/len(data), 
        labels=['Neutral', 'Positive', 'Negative'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7d5fe0cb20>,
#   <matplotlib.patches.Wedge at 0x7f7d5fe1f040>,
#   <matplotlib.patches.Wedge at 0x7f7d5fe1f520>],
#  [Text(0.05000575777903623, 1.098862786788662, 'Neutral'),
#   Text(-0.19201974542725295, -1.0831105286931952, 'Positive'),
#   Text(1.0907199466653261, -0.1425833017796551, 'Negative')])

# %%
positive = data.query('sentiment == "Positive"'); positive[['Ville', 'commentaire']].head(5)
# Out:
#                  Ville                                        commentaire
# 0    Ambérieu-en-Bugey  Ville très agréable, tranquille et disposant d...
# 3    Ambérieu-en-Bugey  C’est une belle ville mais peu d’activités (sp...
# 6  Ambérieux-en-Dombes  Très bonne commune mais pas de tri des déchets...
# 8               Arbent  Positif : de belles forêts et beaux lacs pas l...
# 9      Arboys en Bugey  Petite ville sympathique dotée de toutes les c...

# %%
neutral = data.query('sentiment == "Neutral"'); neutral[['Ville', 'commentaire']].head(5)
# Out:
#                Ville                                        commentaire
# 1  Ambérieu-en-Bugey  La police et la gendarmerie peuvent se montrer...
# 2  Ambérieu-en-Bugey                   Ville ou sa ne vis pas beaucoup
# 4  Ambérieu-en-Bugey  Aspects positifs: la mixité sociale, cohabitat...
# 5  Ambérieu-en-Bugey  Ville de province, sans trop d'incivilités. Be...
# 7           Ambronay          Je ne suis pas prêt de partir de ma ville

# %%
negative = data.query('sentiment == "Negative"'); negative[['Ville', 'commentaire']].head(5)
# Out:
#              Ville                                        commentaire
# 25      Valserhône                                       Catastrophe
# 28      Valserhône  Bellegarde, c'est la ville du quart monde, il ...
# 134       Jasseron  Pas assez de commerce. Habitants désagréables....
# 195        Oyonnax  Ville très très dangereuse, rien en magasin, m...
# 217  Pont-de-Veyle  C'est un village proche d'une ville difficile ...

# %%
data['score_estimation'] = data[['Sécurité', 'Éducation', 'Sport / Loisir', 'Environnement', 'Vie pratique']].mean(axis=1)

# %% [markdown]
# ### Confusion matrix

# %%
confusion_matrix = pd.crosstab(data['score_estimation'], data['sentiment'], rownames=['Actual'], colnames=['Predicted'])

# %%
sns.set(rc={"figure.figsize":(12, 8)})
sns.heatmap(confusion_matrix.sort_index(ascending=False), 
            linewidths=.5, center=0,
            xticklabels=['Negative', 'Neutral', 'Positive'])
plt.show()

# %% [markdown]
# ### Words cloud per types of sentiment

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
def generate_word(df, nbr_words, filename):
    df_word_frequency = df.CommentAferPreproc.str.split(expand=True).stack().value_counts().reset_index() 
    df_word_frequency.columns = ['Word', 'Frequency']

    words_list = df_word_frequency[:nbr_words]['Word']
    words_str = ' '.join(str(e) for e in list(words_list))
    wordcloud = WordCloud(background_color = 'white', stopwords = STOP_WORDS, max_words = 50).generate(words_str)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show();
    plt.savefig(filename)

# %%
generate_word(positive, 50, '../../wordcloud-positif.png')

# %%
generate_word(neutral, 50, '../../wordcloud-neute.png')

# %%
generate_word(negative, 50, '../../wordcloud-negatif.png')

# %%
data.to_csv('../../nlp_analysis.csv')
