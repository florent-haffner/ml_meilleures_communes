# %%
import numpy as np
np.set_printoptions(threshold=10000,suppress=True)
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import gc

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
def count_na(df) : 
    mask = df.isna().sum() > 0
    missing_values = df.isna().sum().sort_values(ascending=False)[mask]
    display(missing_values)
    
def count_na_percentage(df) : 
    mask = df.isna().sum() > 0
    missing_values_percentage = df.isna().sum().sort_values(ascending=False)[mask]/len(df)*100
    display(missing_values_percentage)

# %% [markdown]
# # Lecture des données

# %%
data=pd.read_excel('./donneeSite.xlsx', index_col="Ville")
data.head(3)
# Out:
#                          Insee  Code_postal Nb_habitants Superficie  \
# Ville
# L'Abergement-Clémenciat   1001         1400          767     16 km²
# L'Abergement-de-Varey     1002         1640          241      9 km²
# Ambérieu-en-Bugey         1004         1500       14 127     25 km²
#
#                         Pop_densite Pop_active Taux_chomage Revenu_moyen  \
# Ville
# L'Abergement-Clémenciat    48 h/km²        49%         4.3%  22 228 €/an
# L'Abergement-de-Varey      27 h/km²      50.6%         4.1%  22 883 €/an
# Ambérieu-en-Bugey         565 h/km²      47.5%         7.5%  19 735 €/an
#
#                         Prix_moyen  Note_global  ...  Pharmacie  Maternelle  \
# Ville                                            ...
# L'Abergement-Clémenciat    1 938 €          NaN  ...          0           1
# L'Abergement-de-Varey      1 130 €          NaN  ...          0           0
# Ambérieu-en-Bugey          2 005 €          3.8  ...          6           5
#
#                          Primaire  Collège  Lycée  Securite  Education  \
# Ville
# L'Abergement-Clémenciat         1        0      0       NaN        NaN
# L'Abergement-de-Varey           0        0      0       NaN        NaN
# Ambérieu-en-Bugey               4        2      2       4.0        3.8
#
#                          Loisir / Sport  Environnement  Pratique
# Ville
# L'Abergement-Clémenciat             NaN            NaN       NaN
# L'Abergement-de-Varey               NaN            NaN       NaN
# Ambérieu-en-Bugey                   3.8            4.0       3.3
#
# [3 rows x 47 columns]

# %%
data = data.drop(labels=["Securite", "Education","Loisir / Sport","Environnement","Pratique","Note_global","Code_postal","Insee"], axis=1)

# %%
data.dtypes
# Out:
# Nb_habitants                object
# Superficie                  object
# Pop_densite                 object
# Pop_active                  object
# Taux_chomage                object
# Revenu_moyen                object
# Prix_moyen                  object
# Agriculteurs                 int64
# Artisants/Commercants        int64
# Cadres                       int64
# Profession intermédiaire     int64
# Employes                     int64
# Ouvriers                     int64
# Retraites                    int64
# Sans emploie                 int64
# 0-14 ans                     int64
# 15-29 ans                    int64
# 30-44 ans                    int64
# 45-59 ans                    int64
# 60-74 ans                    int64
# 75-89 ans                    int64
# 90+ ans                      int64
# Hypermarché                  int64
# Supermarché                  int64
# Boulangerie                  int64
# Boucherie                    int64
# Station service              int64
# Banque                       int64
# La poste                     int64
# Coiffeur                     int64
# Vétérinaire                  int64
# Restaurant                   int64
# Médecin                      int64
# Dentiste                     int64
# Pharmacie                    int64
# Maternelle                   int64
# Primaire                     int64
# Collège                      int64
# Lycée                        int64
# dtype: object

# %%
data["Nb_habitants"] = data["Nb_habitants"].astype(str).str.replace('\s+', '').astype(int)

# %%
data
# Out:
#                          Nb_habitants Superficie  Pop_densite Pop_active  \
# Ville
# L'Abergement-Clémenciat           767     16 km²     48 h/km²        49%
# L'Abergement-de-Varey             241      9 km²     27 h/km²      50.6%
# Ambérieu-en-Bugey               14127     25 km²    565 h/km²      47.5%
# Ambérieux-en-Dombes              1619     16 km²    101 h/km²      51.8%
# Ambléon                           109      6 km²     18 h/km²      52.3%
# ...                               ...        ...          ...        ...
# Villers-en-Arthies                508      8 km²     64 h/km²        51%
# Villiers-Adam                     851     10 km²     85 h/km²      47.7%
# Villiers-le-Bel                 27564      7 km²  3 938 h/km²      43.9%
# Villiers-le-Sec                   179      3 km²     60 h/km²      55.3%
# Wy-dit-Joli-Village               326      8 km²     41 h/km²      54.6%
#
#                         Taux_chomage Revenu_moyen Prix_moyen  Agriculteurs  \
# Ville
# L'Abergement-Clémenciat         4.3%  22 228 €/an    1 938 €             2
# L'Abergement-de-Varey           4.1%  22 883 €/an    1 130 €             0
# Ambérieu-en-Bugey               7.5%  19 735 €/an    2 005 €             0
# Ambérieux-en-Dombes             4.1%  23 183 €/an    2 442 €             0
# Ambléon                         7.3%           NC    1 155 €             0
# ...                              ...          ...        ...           ...
# Villers-en-Arthies              4.1%  26 675 €/an    2 150 €             0
# Villiers-Adam                   4.1%  28 405 €/an    3 343 €             0
# Villiers-le-Bel                 9.6%  14 323 €/an    2 449 €             0
# Villiers-le-Sec                 6.7%  25 444 €/an    2 741 €             0
# Wy-dit-Joli-Village             2.5%  28 514 €/an    2 674 €             0
#
#                          Artisants/Commercants  Cadres  ...  Coiffeur  \
# Ville                                                   ...
# L'Abergement-Clémenciat                      3      10  ...         0
# L'Abergement-de-Varey                        9       7  ...         0
# Ambérieu-en-Bugey                            2       6  ...        23
# Ambérieux-en-Dombes                          7       7  ...         1
# Ambléon                                      0       5  ...         0
# ...                                        ...     ...  ...       ...
# Villers-en-Arthies                           4       6  ...         0
# Villiers-Adam                                4      18  ...         1
# Villiers-le-Bel                              2       3  ...        20
# Villiers-le-Sec                              3      14  ...         0
# Wy-dit-Joli-Village                          6      15  ...         0
#
#                          Vétérinaire  Restaurant  Médecin  Dentiste  \
# Ville
# L'Abergement-Clémenciat            0           1        0         0
# L'Abergement-de-Varey              0           0        0         0
# Ambérieu-en-Bugey                  2          38      176        15
# Ambérieux-en-Dombes                0           6        2         0
# Ambléon                            1           0        0         0
# ...                              ...         ...      ...       ...
# Villers-en-Arthies                 0           0        0         0
# Villiers-Adam                      0           0        0         0
# Villiers-le-Bel                    2          68       35        19
# Villiers-le-Sec                    0           0        0         0
# Wy-dit-Joli-Village                0           0        0         0
#
#                          Pharmacie  Maternelle  Primaire  Collège  Lycée
# Ville
# L'Abergement-Clémenciat          0           1         1        0      0
# L'Abergement-de-Varey            0           0         0        0      0
# Ambérieu-en-Bugey                6           5         4        2      2
# Ambérieux-en-Dombes              1           1         1        0      0
# Ambléon                          0           0         0        0      0
# ...                            ...         ...       ...      ...    ...
# Villers-en-Arthies               0           0         1        0      0
# Villiers-Adam                    0           1         1        0      0
# Villiers-le-Bel                  9          12        12        5      2
# Villiers-le-Sec                  0           0         0        0      0
# Wy-dit-Joli-Village              0           0         1        0      0
#
# [33661 rows x 39 columns]

# %%
data["Superficie"] = data["Superficie"].astype(str).str.replace('km²', '').astype(int)

# %%
data["Pop_densite"] = data["Pop_densite"].astype(str).str.replace('\s+', '').str.replace('h/km²', '').astype(int)

# %%
data["Pop_active"] = data["Pop_active"].astype(str).str.replace('%', '').astype(float)

# %%
data["Taux_chomage"] = data["Taux_chomage"].astype(str).str.replace('%', '').astype(float)

# %%
data["Revenu_moyen"] = data["Revenu_moyen"].astype(str).str.replace('\s+', '').str.replace('€/an', '')
data["Revenu_moyen"] = data["Revenu_moyen"].replace('NC',np.nan).astype(float)

# %%
data["Prix_moyen"] = data["Prix_moyen"].astype(str).str.replace('\s+', '').str.replace('€', '').replace('NC',np.nan).astype(float)

# %%
data["Revenu_moyen"] = data["Revenu_moyen"].fillna(value=data["Revenu_moyen"].median())

# %%
data["Prix_moyen"] = data["Prix_moyen"].fillna(value=data["Prix_moyen"].median())

# %% [markdown]
# # X

# %%
X = data.iloc[:,:].values
labels = data.index

# %%
SS = StandardScaler()
SS.fit(X)
Xnorm = SS.transform(X)

# %%
Xnorm[0,:]
# Out:
# array([-0.12724987,  0.03537153, -0.15741575,  0.48304514, -0.33546131,
#         0.57172304,  0.47463783, -0.15337022, -0.16933455,  1.23688662,
#         0.36738385,  0.10344826,  0.67036171, -0.69616759, -1.18103249,
#         0.70578147, -0.08055015, -0.20531266,  0.82360153, -0.47628639,
#        -0.45102466, -0.12693356, -0.17810873, -0.2177246 , -0.0451211 ,
#        -0.20377779, -0.28801443, -0.16898073, -0.31883821, -0.20785758,
#        -0.24522469, -0.11373812, -0.09579213, -0.12293785, -0.19330865,
#        -0.01129824,  0.00151269, -0.21286896, -0.12995057])

# %%
pca=PCA(n_components=0.9)
pca.fit(Xnorm)
# Out:
# PCA(n_components=0.9)

# %%
pca.explained_variance_
# Out:
# array([15.78222917,  5.01031013,  2.23258434,  1.41837119,  1.35723133,
#         1.13527136,  1.0492897 ,  1.00014118,  0.90490255,  0.8599322 ,
#         0.84670564,  0.77516841,  0.6762646 ,  0.65504486,  0.58568438,
#         0.56215806,  0.50796514])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.40466052, 0.12846567, 0.05724405, 0.03636741, 0.03479977,
#        0.02910866, 0.02690406, 0.02564388, 0.02320194, 0.02204889,
#        0.02170976, 0.01987552, 0.0173396 , 0.01679552, 0.0150171 ,
#        0.01441388, 0.01302436])

# %%
pca.components_
# Out:
# array([[ 0.24602701,  0.05116097,  0.12633587, -0.00723028,  0.04446222,
#         -0.0017062 ,  0.05818091, -0.03236129, -0.01162522,  0.03272661,
#          0.00607518,  0.01207232, -0.01592794, -0.01560716,  0.04325849,
#          0.00464433,  0.06859484,  0.0071597 , -0.03124333, -0.02910343,
#          0.00033104,  0.01608642,  0.17015874,  0.22881404,  0.24519637,
#          0.23686832,  0.21089636,  0.2415055 ,  0.22762647,  0.24596871,
#          0.21081263,  0.23388721,  0.22625727,  0.2344127 ,  0.24689058,
#          0.23928537,  0.24152368,  0.237519  ,  0.2300175 ],
#        [-0.00952094,  0.10814093, -0.06533373, -0.34169577,  0.03426068,
#         -0.22039922, -0.15195093,  0.11685533,  0.02236905, -0.17523638,
#         -0.23308636, -0.12796718, -0.07010376,  0.3466042 , -0.01734705,
#         -0.32507188, -0.23817584, -0.32906211, -0.05719938,  0.3161261 ,
#          0.35273504,  0.22421838,  0.01609015,  0.01367778,  0.016159  ,
#          0.01998066,  0.02687907,  0.01700328,  0.02724909,  0.01034383,
#          0.02146767,  0.01285821,  0.01147439,  0.00540885,  0.01311194,
#         -0.01015084, -0.01142542,  0.01886239,  0.01824995],
#        [ 0.01367534, -0.04999614,  0.10394802,  0.0021589 , -0.25618191,
#          0.42991514,  0.36976967, -0.05000482,  0.1463398 ,  0.41541425,
#          0.2142235 , -0.16810306, -0.4123877 ,  0.13555194, -0.07517676,
#         -0.16318622, -0.1341361 , -0.12437547,  0.18825986,  0.17468612,
#          0.0682288 ,  0.02596235, -0.01837313, -0.00338426, -0.00160838,
#         -0.00900879, -0.01499069,  0.00348014,  0.00156041, -0.00316834,
#          0.0189411 ,  0.01529246, -0.00326768,  0.0163147 ,  0.00199641,
#         -0.01444129, -0.01008706, -0.02219063, -0.02927599],
#        [ 0.02894897, -0.03206536, -0.16599079,  0.3195421 , -0.02550274,
#         -0.01785532, -0.17092257,  0.30184869,  0.13821495, -0.08930394,
#         -0.03231429,  0.0394329 ,  0.14894978, -0.10117171, -0.11589617,
#         -0.28220164, -0.00502387, -0.25319721,  0.61976429,  0.04667224,
#         -0.09405839, -0.28465635, -0.04151154, -0.01785251,  0.03134405,
#          0.02564411, -0.07231617,  0.04752042, -0.05102833,  0.04430146,
#         -0.03894767,  0.08897687,  0.11450758,  0.08619922,  0.03273658,
#         -0.00189399,  0.00356398, -0.01511647,  0.06843156],
#        [ 0.0321414 ,  0.07680184, -0.20047704,  0.04997966, -0.40324966,
#          0.03177234, -0.17175879,  0.25907467, -0.04811692, -0.05852392,
#          0.07669151, -0.12586871,  0.00742647,  0.06234416, -0.55877673,
#          0.22399311, -0.32309017,  0.24819686, -0.26940493,  0.03682763,
#         -0.03509639, -0.07532094, -0.0642683 , -0.02298957,  0.03405317,
#          0.02897969, -0.06409518,  0.05308986, -0.03053471,  0.04816817,
#         -0.0125654 ,  0.0901295 ,  0.11030704,  0.08810838,  0.03465231,
#          0.00682903,  0.02428845, -0.01462135,  0.04896745],
#        [-0.05414809,  0.60929664, -0.25251332,  0.07246312,  0.00450608,
#         -0.04041667,  0.08229887, -0.28634166,  0.42291312, -0.06503185,
#          0.0447847 ,  0.3828402 , -0.06306456, -0.03961504, -0.18651587,
#          0.01289234, -0.06044625,  0.03496173,  0.09149326, -0.01743142,
#          0.01288994,  0.11331975,  0.11009124, -0.00743196, -0.00658489,
#         -0.01301894,  0.14795887, -0.02602394,  0.07583596, -0.01091629,
#          0.09461982, -0.04878331, -0.07598339, -0.08307115, -0.03272471,
#          0.00036911,  0.02439828, -0.00220879, -0.03422372],
#        [ 0.02502464, -0.03840793,  0.05323818, -0.05741892,  0.23095361,
#         -0.19894193,  0.02402858,  0.20635303,  0.68009919, -0.02674778,
#         -0.07890026, -0.27719952, -0.24918488, -0.09073876,  0.22824376,
#          0.14294023, -0.11329243,  0.17455498, -0.14486434,  0.09431082,
#         -0.13028407, -0.22767961, -0.07853179, -0.01373458,  0.0146224 ,
#          0.01610862, -0.08586157, -0.00076487, -0.02834706,  0.01218585,
#         -0.06097797,  0.04873963,  0.03698614,  0.03658083,  0.01028908,
#          0.00713111,  0.00246507, -0.01608863,  0.01223129],
#        [-0.04431545,  0.42797009, -0.24809479, -0.04932338, -0.25353896,
#          0.0011027 , -0.09454448,  0.34360273, -0.12968098,  0.06166441,
#          0.15475958, -0.42914865, -0.05980806, -0.13650984,  0.39237264,
#          0.05265889,  0.18677662, -0.01997674,  0.07472826, -0.22009502,
#          0.03942617,  0.13536332,  0.11396647, -0.01791145, -0.02203107,
#         -0.02467318,  0.10868241, -0.00939324,  0.02460538, -0.01613035,
#          0.07461944, -0.06104969, -0.0338505 , -0.0638141 , -0.02271667,
#          0.00147065,  0.0152187 ,  0.01369314,  0.01101527],
#        [ 0.02494372,  0.06201396,  0.34248441,  0.02292175, -0.19586238,
#         -0.04119556,  0.22840478,  0.56632739,  0.01286776, -0.00471003,
#         -0.34806584,  0.44393224, -0.18772394, -0.12896652, -0.02918298,
#          0.01844172,  0.10611948,  0.00652605, -0.03576264, -0.14236499,
#          0.09981877,  0.18397838, -0.08266997,  0.0151489 , -0.00590181,
#         -0.00306885, -0.04203907, -0.02157166,  0.00926456, -0.02509142,
#         -0.00124379, -0.00902581, -0.05338277, -0.00457376, -0.0065831 ,
#          0.00116814, -0.00429089,  0.00574772, -0.05924754],
#        [ 0.01071391,  0.06257793,  0.20002595,  0.05572517, -0.1025845 ,
#          0.11289307,  0.22356535, -0.10182074,  0.29529974,  0.07936444,
#         -0.32702984, -0.4081671 ,  0.61212971, -0.03431991, -0.1902162 ,
#         -0.02373177,  0.05983224, -0.04633899,  0.0020553 , -0.16532348,
#          0.08926622,  0.19739644, -0.06781178,  0.01239195, -0.00102481,
#          0.0024534 , -0.01736023, -0.0033764 ,  0.01140373, -0.01431011,
#          0.0248986 , -0.00167527, -0.03867197, -0.00249092, -0.00614673,
#         -0.0007053 ,  0.0018241 ,  0.00435796, -0.04440465],
#        [-0.00965175,  0.3617843 ,  0.21602954,  0.16485166,  0.53644163,
#         -0.05104238,  0.20648009,  0.24498144, -0.29903437,  0.11966957,
#          0.03138467, -0.20180296, -0.00442236,  0.09006661, -0.29486411,
#         -0.04918396, -0.04758452,  0.01629534, -0.05005667,  0.12334329,
#         -0.09425597, -0.23846733,  0.14361358,  0.03049251, -0.02008307,
#         -0.02353772,  0.08903786, -0.05152362,  0.01228182, -0.0370749 ,
#          0.04709512, -0.07817267, -0.13110675, -0.08730677, -0.03617543,
#          0.014743  ,  0.01079378,  0.00972619, -0.06086681],
#        [-0.00453729, -0.21336407,  0.10584406,  0.12891808,  0.28010424,
#         -0.16225678, -0.09652148,  0.11034399,  0.13796242, -0.11562723,
#          0.49284048, -0.1096045 , -0.12705972, -0.08085975, -0.27864852,
#         -0.02755678,  0.02071043,  0.00091835,  0.11018757, -0.25940555,
#          0.15172716,  0.55065694, -0.05456174,  0.01966792,  0.00005862,
#          0.0110526 , -0.01275999,  0.00417304,  0.01972123, -0.00340827,
#         -0.00998241, -0.00742744, -0.00847846,  0.0020926 ,  0.00510458,
#         -0.01259631, -0.02305221,  0.02896206,  0.00049788],
#        [ 0.07957735,  0.3238991 ,  0.33101168, -0.05215436, -0.16972218,
#         -0.13478268,  0.19900087, -0.12316319, -0.1109946 , -0.37610522,
#          0.35003688, -0.02838596,  0.08676181,  0.02524172,  0.14590259,
#         -0.04187887, -0.0439978 , -0.00579015,  0.06326378,  0.0909714 ,
#         -0.02221586, -0.10609829, -0.48355501, -0.00832338,  0.04186214,
#          0.04033792, -0.23141442, -0.01307543,  0.05276977,  0.01685   ,
#         -0.11333392,  0.11007659,  0.01952361,  0.07738304,  0.0188875 ,
#          0.05841448,  0.05468867, -0.04097113, -0.08111286],
#        [ 0.03085273,  0.17026782, -0.15598366,  0.06231749,  0.27569122,
#          0.02554963, -0.13081528, -0.05822394, -0.18547373,  0.42011582,
#         -0.25397931,  0.03563594, -0.02523744, -0.0663344 ,  0.14712931,
#          0.0876419 , -0.35728934,  0.12791929,  0.15570812, -0.06259098,
#         -0.0608394 ,  0.29531796, -0.43277569, -0.04072419,  0.03028661,
#          0.02860641, -0.18361284,  0.03720653,  0.0547395 ,  0.03680912,
#         -0.06426562,  0.11111623,  0.10769873,  0.09810309,  0.03087005,
#          0.01976867,  0.02593295, -0.02595757,  0.00433508],
#        [ 0.03528558,  0.09785713,  0.41433293, -0.09745726, -0.19560654,
#         -0.3250993 , -0.42342252, -0.24897902,  0.00934417,  0.29860167,
#         -0.07081161, -0.07460582, -0.19840004, -0.03838122, -0.15379942,
#          0.07058515, -0.05733105, -0.12843376,  0.15512413, -0.30300896,
#          0.1145736 , -0.25641943,  0.05499741,  0.04505383, -0.01539682,
#         -0.00698129, -0.01374528, -0.0456566 , -0.02328299, -0.03564007,
#         -0.03392579, -0.08594376, -0.09382433, -0.04618026, -0.01365197,
#          0.06822995,  0.04631297,  0.04949509, -0.02458271],
#        [ 0.00551904,  0.10564796, -0.15080368,  0.05151846,  0.05169214,
#          0.01826003, -0.15807518, -0.03898854,  0.06836153,  0.16340757,
#         -0.05992916, -0.03621225, -0.17195022,  0.12870878, -0.22854305,
#         -0.14318739,  0.67335626, -0.20746625, -0.30349927,  0.03045676,
#         -0.12540376, -0.0158257 , -0.36927907, -0.04375266, -0.00001092,
#         -0.00914663, -0.11611803,  0.03825948,  0.0617874 ,  0.00791087,
#         -0.05242029,  0.04378121,  0.08708801,  0.04388307,  0.01107273,
#          0.01788048,  0.0183697 , -0.01005978,  0.03222151],
#        [-0.00624927, -0.05639643, -0.15155305,  0.08522754,  0.05460218,
#         -0.01388241,  0.21581966, -0.08272426, -0.06663199, -0.28097548,
#         -0.24954936, -0.13426096, -0.24985652,  0.55830188, -0.03680439,
#          0.28412755,  0.11612006,  0.14571236,  0.30856816, -0.35724529,
#          0.13121668, -0.09123616, -0.06014075, -0.01381943,  0.01057537,
#          0.01281531,  0.00221852,  0.00650414,  0.01613957,  0.01869655,
#          0.01353879,  0.03274948,  0.02067427,  0.01184646,  0.00412693,
#         -0.00751375,  0.00208372, -0.01612641, -0.0073159 ]])

# %%
pca.components_[0,:]
# Out:
# array([ 0.24602701,  0.05116097,  0.12633587, -0.00723028,  0.04446222,
#        -0.0017062 ,  0.05818091, -0.03236129, -0.01162522,  0.03272661,
#         0.00607518,  0.01207232, -0.01592794, -0.01560716,  0.04325849,
#         0.00464433,  0.06859484,  0.0071597 , -0.03124333, -0.02910343,
#         0.00033104,  0.01608642,  0.17015874,  0.22881404,  0.24519637,
#         0.23686832,  0.21089636,  0.2415055 ,  0.22762647,  0.24596871,
#         0.21081263,  0.23388721,  0.22625727,  0.2344127 ,  0.24689058,
#         0.23928537,  0.24152368,  0.237519  ,  0.2300175 ])

# %%
pca.components_[1,:]
# Out:
# array([-0.00952094,  0.10814093, -0.06533373, -0.34169577,  0.03426068,
#        -0.22039922, -0.15195093,  0.11685533,  0.02236905, -0.17523638,
#        -0.23308636, -0.12796718, -0.07010376,  0.3466042 , -0.01734705,
#        -0.32507188, -0.23817584, -0.32906211, -0.05719938,  0.3161261 ,
#         0.35273504,  0.22421838,  0.01609015,  0.01367778,  0.016159  ,
#         0.01998066,  0.02687907,  0.01700328,  0.02724909,  0.01034383,
#         0.02146767,  0.01285821,  0.01147439,  0.00540885,  0.01311194,
#        -0.01015084, -0.01142542,  0.01886239,  0.01824995])

# %% [markdown]
# # Cercle de corrélation

# %%
coef = np.transpose(pca.components_)
cols = ['y'+str(x+1) for x in range(17)]

pc_infos = pd.DataFrame(coef, columns=cols, index=data.iloc[:,:].columns)


plt.Circle((0,0),radius=10, color='g', fill=False)
circle1=plt.Circle((0,0),radius=1, color='g', fill=False)
# Ajouter les axes et donner la limite pour chaque axe
fig, axes= plt.subplots(figsize=(50,50))
axes.set_xlim(-1,1)
axes.set_ylim(-1,1)
fig.gca().add_artist(circle1)
plt.plot([-1,1],[0,0],color='silver',linestyle='-',linewidth=1)
plt.plot([0,0],[-1,1],color='silver',linestyle='-',linewidth=1)
axes.add_artist(circle1)
# Affichage de chaque variable explicative dans la cercle
for idx in range(len(pc_infos["y1"])):
    x = pc_infos["y1"][idx]
    y = pc_infos["y2"][idx]
    plt.plot([0.0,x],[0.0,y],'k-')
    plt.plot(x, y, 'rx')
    plt.annotate(pc_infos.index[idx], xy=(x,y))
plt.xlim((-1,1))
plt.ylim((-1,1))
plt.title("Circle of Correlations")
# Out:
# Text(0.5, 1.0, 'Circle of Correlations')

# %%
X_pca=pca.transform(Xnorm)

# %%
plt.figure(figsize=(100,100))
plt.scatter(X_pca[:, 0], X_pca[:, 1])
for label, x, y in zip(labels, X_pca[:, 0], X_pca[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(-0.2, 0.2), textcoords='offset points')
plt.show()
